# %%
import pandas as pd
import numpy as np

# %%
albums = pd.read_csv(r'F:\Data_Engineering\SpotifyPipeline\data\albums.csv')
# from first column to 11th column + last column
albums = albums.iloc[:, np.r_[0:14, -1]]
#  display albums with truncate = false
albums
# Out:
#                                        track_name                track_id  \
# 0                        What Makes You Beautiful  4cluDES4hQEUhmXj6TXkSo
# 1                                    Gotta Be You  3jJ5NJ3aNWvV70Rd7hgZIH
# 2                                       One Thing  5G2c6FsfTzgYUzageCmfXY
# 3                                  More Than This  0UAB340gAcSMk3r0a8PTag
# 4                                    Up All Night  1I93YiKgu2P5pwprWmziPI
# ...                                           ...                     ...
# 9271    Symphony No. 3 "Slavyanskaya": I. Allegro  0CJ0lknKHIT5Tlo3VCEwn3
# 9272     Symphony No. 3 "Slavyanskaya": Ii. Waltz  5KUMgcnK6FBd2FhjYNk0PQ
# 9273  Symphony No. 3 "Slavyanskaya": Iii. Scherzo  2RtrRzDzVYgIyYoOLT2Txh
# 9274   Symphony No. 3 "Slavyanskaya": Iv. Allegro  1YzA3evT0oX2qT9yZkTjKj
# 9275                             Mavericks (Live)  73n9oVmmb3qCP1tc8bgRHX
#
#       track_number  duration_ms  \
# 0                1       199986
# 1                2       244506
# 2                3       197600
# 3                4       229106
# 4                5       194693
# ...            ...          ...
# 9271             9       344746
# 9272            10       166253
# 9273            11       135840
# 9274            12       274826
# 9275            13       481506
#
#                                                                                          artists  \
# 0                                                                              ['One Direction']
# 1                                                                              ['One Direction']
# 2                                                                              ['One Direction']
# 3                                                                              ['One Direction']
# 4                                                                              ['One Direction']
# ...                                                                                          ...
# 9271  ['Boris Tikhonovich Kozhevnikov', 'North Texas Wind Symphony', 'Eugene Migliaro Corporon']
# 9272  ['Boris Tikhonovich Kozhevnikov', 'North Texas Wind Symphony', 'Eugene Migliaro Corporon']
# 9273  ['Boris Tikhonovich Kozhevnikov', 'North Texas Wind Symphony', 'Eugene Migliaro Corporon']
# 9274  ['Boris Tikhonovich Kozhevnikov', 'North Texas Wind Symphony', 'Eugene Migliaro Corporon']
# 9275                    ['Paul Dooley', 'North Texas Wind Symphony', 'Eugene Migliaro Corporon']
#
#      album_type  total_tracks    album_name release_date          label  \
# 0         album            18  Up All Night   2012-05-25  Syco Music UK
# 1         album            18  Up All Night   2012-05-25  Syco Music UK
# 2         album            18  Up All Night   2012-05-25  Syco Music UK
# 3         album            18  Up All Night   2012-05-25  Syco Music UK
# 4         album            18  Up All Night   2012-05-25  Syco Music UK
# ...         ...           ...           ...          ...            ...
# 9271      album            13   Taylor Made   2018-03-16  GIA WindWorks
# 9272      album            13   Taylor Made   2018-03-16  GIA WindWorks
# 9273      album            13   Taylor Made   2018-03-16  GIA WindWorks
# 9274      album            13   Taylor Made   2018-03-16  GIA WindWorks
# 9275      album            13   Taylor Made   2018-03-16  GIA WindWorks
#
#       album_popularity                album_id               artist_id  \
# 0                   80  6cunQQ7YZisYOoiFu2ywIq  4AK6F7OLvEQ5QYCBNiQWHq
# 1                   80  6cunQQ7YZisYOoiFu2ywIq  4AK6F7OLvEQ5QYCBNiQWHq
# 2                   80  6cunQQ7YZisYOoiFu2ywIq  4AK6F7OLvEQ5QYCBNiQWHq
# 3                   80  6cunQQ7YZisYOoiFu2ywIq  4AK6F7OLvEQ5QYCBNiQWHq
# 4                   80  6cunQQ7YZisYOoiFu2ywIq  4AK6F7OLvEQ5QYCBNiQWHq
# ...                ...                     ...                     ...
# 9271                 1  3luJeNmnVBZYiPZpOLzR36  1MU0DtoPi3KRw38z1NnV5E
# 9272                 1  3luJeNmnVBZYiPZpOLzR36  1MU0DtoPi3KRw38z1NnV5E
# 9273                 1  3luJeNmnVBZYiPZpOLzR36  1MU0DtoPi3KRw38z1NnV5E
# 9274                 1  3luJeNmnVBZYiPZpOLzR36  1MU0DtoPi3KRw38z1NnV5E
# 9275                 1  3luJeNmnVBZYiPZpOLzR36  1MU0DtoPi3KRw38z1NnV5E
#
#                            artist_0  duration_sec
# 0                     One Direction       199.986
# 1                     One Direction       244.506
# 2                     One Direction       197.600
# 3                     One Direction       229.106
# 4                     One Direction       194.693
# ...                             ...           ...
# 9271  Boris Tikhonovich Kozhevnikov       344.746
# 9272  Boris Tikhonovich Kozhevnikov       166.253
# 9273  Boris Tikhonovich Kozhevnikov       135.840
# 9274  Boris Tikhonovich Kozhevnikov       274.826
# 9275                    Paul Dooley       481.506
#
# [9276 rows x 15 columns]

# %%
artists = pd.read_csv(r'F:\Data_Engineering\SpotifyPipeline\data\artists.csv')
# artists = artists.iloc[:, np.r_[0:5, -1]]
artists
# Out:
#                          id                       name  artist_popularity  \
# 0    4AK6F7OLvEQ5QYCBNiQWHq              One Direction                 84
# 1    6KImCVD70vtIoJWnq6nGn3               Harry Styles                 84
# 2    6w60ExNMjs0gd4ioh7GMRI                 BLP KOSHER                 59
# 3    7m0BsF0t3K9WQFgKoPejfk                     ArrDee                 63
# 4    1Hsdzj7Dlq2I7tHP7501T4                Niall Horan                 74
# ..                      ...                        ...                ...
# 858  4vyXjivS5Uy1AMrL2jw2Qs              Taylor Taylor                  4
# 859  65WAeYJTdfqpKQmYfgmF0k               Music Mayhem                  5
# 860  5NayZvBPFf6ANFWLfEr9aN             Taylor Marissa                  0
# 861  5aEMARkjW3SYYnGLTLgCks          Karaoke - Ameritz                 20
# 862  1MU0DtoPi3KRw38z1NnV5E  North Texas Wind Symphony                 34
#
#                                          artist_genres  followers  \
# 0    ['boy band', 'pop', 'post-teen pop', 'talent s...   35837153
# 1                                              ['pop']   32774246
# 2                                                   []     208183
# 3                                       ['uk hip hop']     967200
# 4                                              ['pop']    9920240
# ..                                                 ...        ...
# 858                                                 []        972
# 859                                                 []        306
# 860                                                 []         96
# 861                                        ['karaoke']       2367
# 862                  ['concert band', 'wind symphony']       9536
#
#           genre_0        genre_1        genre_2      genre_3 genre_4 genre_5  \
# 0        boy band            pop  post-teen pop  talent show     NaN     NaN
# 1             pop            NaN            NaN          NaN     NaN     NaN
# 2             NaN            NaN            NaN          NaN     NaN     NaN
# 3      uk hip hop            NaN            NaN          NaN     NaN     NaN
# 4             pop            NaN            NaN          NaN     NaN     NaN
# ..            ...            ...            ...          ...     ...     ...
# 858           NaN            NaN            NaN          NaN     NaN     NaN
# 859           NaN            NaN            NaN          NaN     NaN     NaN
# 860           NaN            NaN            NaN          NaN     NaN     NaN
# 861       karaoke            NaN            NaN          NaN     NaN     NaN
# 862  concert band  wind symphony            NaN          NaN     NaN     NaN
#
#     genre_6 genre_7
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ..      ...     ...
# 858     NaN     NaN
# 859     NaN     NaN
# 860     NaN     NaN
# 861     NaN     NaN
# 862     NaN     NaN
#
# [863 rows x 13 columns]

# %%
# check null values
artists.isnull().sum()
# Out:
# id                     0
# name                   0
# artist_popularity      0
# artist_genres          0
# followers              0
# genre_0              565
# genre_1              767
# genre_2              815
# genre_3              845
# genre_4              857
# genre_5              860
# genre_6              860
# genre_7              862
# dtype: int64

# %%
features = pd.read_csv(r'F:\Data_Engineering\SpotifyPipeline\data\features.csv')
features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.726  0.7870    4    -2.494     1       0.0737       0.00900
# 1            0.495  0.5830    8    -4.531     1       0.0249       0.37400
# 2            0.713  0.7180    2    -3.806     1       0.0278       0.00233
# 3            0.498  0.7150    0    -4.446     1       0.0315       0.06070
# 4            0.606  0.9290    0    -2.182     1       0.0550       0.02300
# ...            ...     ...  ...       ...   ...          ...           ...
# 9270         0.267  0.2290   10   -16.271     0       0.0367       0.97000
# 9271         0.283  0.0634    1   -22.036     1       0.0358       0.97800
# 9272         0.362  0.3650    5   -15.799     1       0.0347       0.93600
# 9273         0.316  0.2590    5   -15.269     1       0.0458       0.97300
# 9274         0.390  0.4140    2   -15.510     0       0.0419       0.90500
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0                0.000    0.0596    0.888  124.990  audio_features
# 1                0.000    0.0781    0.603   84.969  audio_features
# 2                0.000    0.0838    0.656  126.999  audio_features
# 3                0.000    0.2740    0.225  151.809  audio_features
# 4                0.000    0.1010    0.622  139.022  audio_features
# ...                ...       ...      ...      ...             ...
# 9270             0.902    0.1310    0.223   83.368  audio_features
# 9271             0.884    0.0950    0.224  141.176  audio_features
# 9272             0.900    0.1590    0.824  141.461  audio_features
# 9273             0.872    0.3290    0.263  174.034  audio_features
# 9274             0.777    0.1750    0.165  112.288  audio_features
#
#                           id                                   uri  \
# 0     4cluDES4hQEUhmXj6TXkSo  spotify:track:4cluDES4hQEUhmXj6TXkSo
# 1     3jJ5NJ3aNWvV70Rd7hgZIH  spotify:track:3jJ5NJ3aNWvV70Rd7hgZIH
# 2     5G2c6FsfTzgYUzageCmfXY  spotify:track:5G2c6FsfTzgYUzageCmfXY
# 3     0UAB340gAcSMk3r0a8PTag  spotify:track:0UAB340gAcSMk3r0a8PTag
# 4     1I93YiKgu2P5pwprWmziPI  spotify:track:1I93YiKgu2P5pwprWmziPI
# ...                      ...                                   ...
# 9270  0CJ0lknKHIT5Tlo3VCEwn3  spotify:track:0CJ0lknKHIT5Tlo3VCEwn3
# 9271  5KUMgcnK6FBd2FhjYNk0PQ  spotify:track:5KUMgcnK6FBd2FhjYNk0PQ
# 9272  2RtrRzDzVYgIyYoOLT2Txh  spotify:track:2RtrRzDzVYgIyYoOLT2Txh
# 9273  1YzA3evT0oX2qT9yZkTjKj  spotify:track:1YzA3evT0oX2qT9yZkTjKj
# 9274  73n9oVmmb3qCP1tc8bgRHX  spotify:track:73n9oVmmb3qCP1tc8bgRHX
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4cluDES4hQEU...
# 1     https://api.spotify.com/v1/tracks/3jJ5NJ3aNWvV...
# 2     https://api.spotify.com/v1/tracks/5G2c6FsfTzgY...
# 3     https://api.spotify.com/v1/tracks/0UAB340gAcSM...
# 4     https://api.spotify.com/v1/tracks/1I93YiKgu2P5...
# ...                                                 ...
# 9270  https://api.spotify.com/v1/tracks/0CJ0lknKHIT5...
# 9271  https://api.spotify.com/v1/tracks/5KUMgcnK6FBd...
# 9272  https://api.spotify.com/v1/tracks/2RtrRzDzVYgI...
# 9273  https://api.spotify.com/v1/tracks/1YzA3evT0oX2...
# 9274  https://api.spotify.com/v1/tracks/73n9oVmmb3qC...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4clu...       199987
# 1     https://api.spotify.com/v1/audio-analysis/3jJ5...       244507
# 2     https://api.spotify.com/v1/audio-analysis/5G2c...       197600
# 3     https://api.spotify.com/v1/audio-analysis/0UAB...       229107
# 4     https://api.spotify.com/v1/audio-analysis/1I93...       194693
# ...                                                 ...          ...
# 9270  https://api.spotify.com/v1/audio-analysis/0CJ0...       344747
# 9271  https://api.spotify.com/v1/audio-analysis/5KUM...       166253
# 9272  https://api.spotify.com/v1/audio-analysis/2Rtr...       135840
# 9273  https://api.spotify.com/v1/audio-analysis/1YzA...       274827
# 9274  https://api.spotify.com/v1/audio-analysis/73n9...       481507
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 9270               4
# 9271               3
# 9272               4
# 9273               4
# 9274               3
#
# [9275 rows x 18 columns]

# %%
tracks = pd.read_csv(r'F:\Data_Engineering\SpotifyPipeline\data\tracks.csv')
tracks
# Out:
#                           id  track_popularity  explicit
# 0     4cluDES4hQEUhmXj6TXkSo                84     False
# 1     3jJ5NJ3aNWvV70Rd7hgZIH                61     False
# 2     5G2c6FsfTzgYUzageCmfXY                71     False
# 3     0UAB340gAcSMk3r0a8PTag                61     False
# 4     1I93YiKgu2P5pwprWmziPI                61     False
# ...                      ...               ...       ...
# 9271  0CJ0lknKHIT5Tlo3VCEwn3                 0     False
# 9272  5KUMgcnK6FBd2FhjYNk0PQ                 0     False
# 9273  2RtrRzDzVYgIyYoOLT2Txh                 0     False
# 9274  1YzA3evT0oX2qT9yZkTjKj                 0     False
# 9275  73n9oVmmb3qCP1tc8bgRHX                 0     False
#
# [9276 rows x 3 columns]

# %%
# tracks where explicit = True
explicit_tracks = tracks[tracks['explicit'] == True]
# join with albums to display track name and album name
explicit_tracks = explicit_tracks.merge(albums, left_on='id', right_on='track_id', how='left')

# %%
# explicit_tracks['track_name'].head(10)
# display track_name and artists
explicit_tracks[['track_name', 'artists']].head(20)
# Out:
#                                    track_name  \
# 0                               One Direction
# 1                               One Direction
# 2                             Too Much To Ask
# 3                               Want You Back
# 4                              Me, Myself & I
# 5                                Best Friends
# 6                                  Moodswings
# 7         One Direction (Feat. Pipo Martinez)
# 8                                   Good Life
# 9                                      Old Me
# 10                        Not In The Same Way
# 11                                 Pillowtalk
# 12                                   It'S You
# 13                      Wrong (Feat. Kehlani)
# 14                                   Lucozade
# 15                                     Bright
# 16                          She Don'T Love Me
# 17  Not That Kinda Girl (Feat. Missy Elliott)
# 18                                       Dope
# 19                              One Direction
#
#                                               artists
# 0                                      ['BLP KOSHER']
# 1                          ['ArrDee', 'Bugzy Malone']
# 2                                     ['Niall Horan']
# 3                             ['5 Seconds of Summer']
# 4                             ['5 Seconds of Summer']
# 5                             ['5 Seconds of Summer']
# 6                             ['5 Seconds of Summer']
# 7   ['Junior Caldera', 'Yung Iverson', 'RK wavy', ...
# 8                                     ['OneRepublic']
# 9                             ['5 Seconds of Summer']
# 10                            ['5 Seconds of Summer']
# 11                                           ['ZAYN']
# 12                                           ['ZAYN']
# 13                                ['ZAYN', 'Kehlani']
# 14                                           ['ZAYN']
# 15                                           ['ZAYN']
# 16                                           ['ZAYN']
# 17                 ['Fifth Harmony', 'Missy Elliott']
# 18                                  ['Fifth Harmony']
# 19                                     ['Danny Dean']

# %%
# tracks where artists is Taylor Swift
taylor_tracks = albums[albums['artist_0'] == 'Taylor Swift']['track_name']
taylor_tracks = pd.DataFrame(taylor_tracks)

# %%
# Out:
#                                              track_name
# 730                                             Crazier
# 3613             Welcome To New York (Taylor'S Version)
# 3614                     Blank Space (Taylor'S Version)
# 3615                           Style (Taylor'S Version)
# 3616                Out Of The Woods (Taylor'S Version)
# ...                                                 ...
# 6273  Mary'S Song (Oh My My My) - Instrumental W/ Bg...
# 6274               Our Song - Instrumental W/ Bg Vocals
# 6275  I'M Only Me When I'M With You - Instrumental W...
# 6276              Invisible - Instrumental W/ Bg Vocals
# 6277  A Perfectly Good Heart - Instrumental W/ Bg Vo...
#
# [1193 rows x 1 columns]
